# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Intro
#
# This project is focused on analysing the WeRateDongs tweeter account, where data about the tweets, the dog images, ratings, and tweeter metrics was gathered to glean some insight that may help improving the acitivity of promoting the account and dogs images.
#
# The analysis led to the following outcomes:
#
# ### Insights:

# %% [markdown]
# 1. Charlie, and Coppere are the most popular dog names

# %%
from IPython.display import Image
Image("img/Dog-names-count-viz.png")

# %% [markdown]
# 2. Pupper is by far the most dog type, followed by dogoog and puppo

# %%
from IPython.display import Image
Image("./img/Dog-types-count-viz.png")

# %% [markdown]
# 3. Golden Retriever is by far the most popular dog breed, followed by Labrador Retriever and Pembroke

# %%
from IPython.display import Image
Image("img/Dog-breed-count-viz.png")

# %% [markdown]
# 4. The visulisations showed the users were most engaged on the 6 AM hour of the day, where retweet and favourite counts were very high. Also on average dogs received higher rating at 6 AM hour of the morning. This can be helpful for tweeting dog images at a time of the day when people are more likely to give the dog a higher rating and also interact with the most (e.g. retweet and favourite).

# %%
from IPython.display import Image
Image("img/retweet-count-viz.png")

# %%
Image("img/favorite-count-viz.png")

# %%
Image("img/rating-numerator-viz.png")
